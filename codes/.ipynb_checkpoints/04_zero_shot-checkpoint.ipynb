# %% [markdown]
# We will now attempt to use a pretrained model called 'zero shot classification' on HuggingFace to classify the locations. We will evaluate the pretrained model by comparing its classification to some hand labelled location types before a decision will be made to employ it.

# %% [markdown]
# ## Contents:
# - [Instantiate Classifier Pipeline from HuggingFace](#Instantiate-Classifier-Pipeline-from-HuggingFace)
# - [Loading of Libraries](#Loading-of-Libraries)
# - [Loading of Dataset](#Loading-of-Dataset)
# - [Zero Shot Pretrained Model Evaluation](#Zero-Shot-Pretrained-Model-Evaluation)

# %% [markdown]
# ## Instantiate Classifier Pipeline from HuggingFace

# %%
# Instantiate zero shot classifier pipeline based on documentation on HuggingFace
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# 2023-02-21 11:12:37.324567: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Loading of Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading of Dataset

# %%
# Load data
recsys_df = pd.read_csv('./output/recsys_df_name.csv')
print(recsys_df.shape)
recsys_df.head(3)
# Out:
# (177607, 7)
#      profile_id  location_id                  cts  sentiment_pred  \
# 0  4.519805e+06    1178180.0  2016-06-09 22:13:32               3
# 1  2.594847e+08    1178180.0  2019-05-30 23:17:22               3
# 2  6.364797e+09    1178180.0  2019-05-26 15:27:27               3
#
#           name                    city  cd
# 0  la famiglia  London, United Kingdom  GB
# 1  la famiglia  London, United Kingdom  GB
# 2  la famiglia  London, United Kingdom  GB

# %% [markdown]
# ## Zero Shot Pretrained Model Evaluation

# %% [markdown]
# #### Using 100 rows for comparison

# %%
# Save and export first 100 rows for zero shot comparison
recsys_df_100 = recsys_df.head(100)
recsys_df_100.to_csv('./output/recsys_df_100.csv', index=False)

# %%
# Function for zero shot prediction
def zero_shot_preds(df, classifier, topic_list):
    df["zero_shot_output"] = df["name"].progress_apply(
        classifier, candidate_labels=topic_list
    )
    zero_shot_df = pd.json_normalize(df["zero_shot_output"])
    zero_shot_df["zero_shot_result"] = zero_shot_df['labels'].str[0]
    
    return zero_shot_df

# %%
# %%time
zero_shot_df_100 = zero_shot_preds(recsys_df_100,classifier,['boat_tours_and_water_sports', 'pubs_and_nightlife', 'sights_and_landmarks', 'spas_and_wellness', 'fun_and_games', 'museums', 'classes_and_workshops', 'nature_and_parks', 'markets', 'neighbourhoods', 'others'])
# Out:
# 100%|█████████████████████████████████████████| 100/100 [06:47<00:00,  4.08s/it]
# CPU times: user 12min 12s, sys: 11 s, total: 12min 23s
# Wall time: 6min 47s
# /var/folders/w4/cdf3yttj10d7ynthq7lkp5fh0000gn/T/ipykernel_5135/2275498562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zero_shot_output"] = df["name"].progress_apply(

# %%
zero_shot_df_100
# Out:
#        sequence                                             labels  \
# 0   la famiglia  [others, sights_and_landmarks, fun_and_games, ...
# 1   la famiglia  [others, sights_and_landmarks, fun_and_games, ...
# 2   la famiglia  [others, sights_and_landmarks, fun_and_games, ...
# 3    green park  [nature_and_parks, sights_and_landmarks, fun_a...
# 4    green park  [nature_and_parks, sights_and_landmarks, fun_a...
# ..          ...                                                ...
# 95   gossip.com  [others, neighbourhoods, markets, sights_and_l...
# 96   gossip.com  [others, neighbourhoods, markets, sights_and_l...
# 97   gossip.com  [others, neighbourhoods, markets, sights_and_l...
# 98   gossip.com  [others, neighbourhoods, markets, sights_and_l...
# 99   gossip.com  [others, neighbourhoods, markets, sights_and_l...
#
#                                                scores  zero_shot_result
# 0   [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 1   [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 2   [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 3   [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks
# 4   [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks
# ..                                                ...               ...
# 95  [0.4013848900794983, 0.11936227232217789, 0.08...            others
# 96  [0.4013848900794983, 0.11936227232217789, 0.08...            others
# 97  [0.4013848900794983, 0.11936227232217789, 0.08...            others
# 98  [0.4013848900794983, 0.11936227232217789, 0.08...            others
# 99  [0.4013848900794983, 0.11936227232217789, 0.08...            others
#
# [100 rows x 4 columns]

# %%
# Load true (hand labelled) location type
recsys_df_100_true = pd.read_csv('./output/recsys_df_100_true.csv')
print(recsys_df_100_true.shape)
recsys_df_100_true.head()
# Out:
# (100, 8)
#    profile_id  location_id                  cts  sentiment_pred         name  \
# 0     4519805      1178180  2016-06-09 22:13:32               3  la famiglia
# 1   259484657      1178180  2019-05-30 23:17:22               3  la famiglia
# 2  6364796956      1178180  2019-05-26 15:27:27               3  la famiglia
# 3   221389356    857670431  2019-05-30 21:41:15               2   green park
# 4   624306558    857670431   2019-05-30 7:56:50               3   green park
#
#                      city  cd         type_true
# 0  London, United Kingdom  GB            others
# 1  London, United Kingdom  GB            others
# 2  London, United Kingdom  GB            others
# 3  London, United Kingdom  GB  nature_and_parks
# 4  London, United Kingdom  GB  nature_and_parks

# %%
# Join both dataset
recsys_df_100 = recsys_df_100_true.join(zero_shot_df_100)
recsys_df_100.head()
# Out:
#    profile_id  location_id                  cts  sentiment_pred         name  \
# 0     4519805      1178180  2016-06-09 22:13:32               3  la famiglia
# 1   259484657      1178180  2019-05-30 23:17:22               3  la famiglia
# 2  6364796956      1178180  2019-05-26 15:27:27               3  la famiglia
# 3   221389356    857670431  2019-05-30 21:41:15               2   green park
# 4   624306558    857670431   2019-05-30 7:56:50               3   green park
#
#                      city  cd         type_true     sequence  \
# 0  London, United Kingdom  GB            others  la famiglia
# 1  London, United Kingdom  GB            others  la famiglia
# 2  London, United Kingdom  GB            others  la famiglia
# 3  London, United Kingdom  GB  nature_and_parks   green park
# 4  London, United Kingdom  GB  nature_and_parks   green park
#
#                                               labels  \
# 0  [others, sights_and_landmarks, fun_and_games, ...
# 1  [others, sights_and_landmarks, fun_and_games, ...
# 2  [others, sights_and_landmarks, fun_and_games, ...
# 3  [nature_and_parks, sights_and_landmarks, fun_a...
# 4  [nature_and_parks, sights_and_landmarks, fun_a...
#
#                                               scores  zero_shot_result
# 0  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 1  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 2  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 3  [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks
# 4  [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks

# %%
# Drop 'sequence','labels','scores' cols
recsys_df_100.drop(['sequence','labels','scores'], axis=1, inplace=True)

# %%
recsys_df_100.head()
# Out:
#    profile_id  location_id                  cts  sentiment_pred         name  \
# 0     4519805      1178180  2016-06-09 22:13:32               3  la famiglia
# 1   259484657      1178180  2019-05-30 23:17:22               3  la famiglia
# 2  6364796956      1178180  2019-05-26 15:27:27               3  la famiglia
# 3   221389356    857670431  2019-05-30 21:41:15               2   green park
# 4   624306558    857670431   2019-05-30 7:56:50               3   green park
#
#                      city  cd         type_true  zero_shot_result
# 0  London, United Kingdom  GB            others            others
# 1  London, United Kingdom  GB            others            others
# 2  London, United Kingdom  GB            others            others
# 3  London, United Kingdom  GB  nature_and_parks  nature_and_parks
# 4  London, United Kingdom  GB  nature_and_parks  nature_and_parks

# %%
# Check accuracy of pretrained model
accuracy_score(recsys_df_100['type_true'].values, recsys_df_100['zero_shot_result'].values)
# Out:
# 0.3

# %% [markdown]
# - The accuracy score of the pretrained model at 0.3 is very poor. We will attempt to compare 200 rows instead.

# %% [markdown]
# #### Using 200 rows for comparison

# %%
# Save and export first 200 rows for zero shot comparison
recsys_df_200 = recsys_df.head(200)
recsys_df_200.to_csv('./output/recsys_df_200.csv', index=False)

# %%
# %%time
zero_shot_df_200 = zero_shot_preds(recsys_df_200,classifier,['boat_tours_and_water_sports', 'pubs_and_nightlife', 'sights_and_landmarks', 'spas_and_wellness', 'fun_and_games', 'museums', 'classes_and_workshops', 'nature_and_parks', 'markets', 'neighbourhoods', 'others'])
# Out:
# 100%|█████████████████████████████████████████| 200/200 [16:34<00:00,  4.97s/it]
# CPU times: user 26min 59s, sys: 31.2 s, total: 27min 30s
# Wall time: 16min 34s
# /var/folders/w4/cdf3yttj10d7ynthq7lkp5fh0000gn/T/ipykernel_5135/2275498562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zero_shot_output"] = df["name"].progress_apply(

# %%
zero_shot_df_200.head()
# Out:
#       sequence                                             labels  \
# 0  la famiglia  [others, sights_and_landmarks, fun_and_games, ...
# 1  la famiglia  [others, sights_and_landmarks, fun_and_games, ...
# 2  la famiglia  [others, sights_and_landmarks, fun_and_games, ...
# 3   green park  [nature_and_parks, sights_and_landmarks, fun_a...
# 4   green park  [nature_and_parks, sights_and_landmarks, fun_a...
#
#                                               scores  zero_shot_result
# 0  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 1  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 2  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 3  [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks
# 4  [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks

# %%
# Load true (hand labelled) location type
recsys_df_200_true = pd.read_csv('./output/recsys_df_200_true.csv')
print(recsys_df_200_true.shape)
recsys_df_200_true.head()
# Out:
# (200, 8)
#    profile_id  location_id                  cts  sentiment_pred         name  \
# 0     4519805    1178180.0  2016-06-09 22:13:32               3  la famiglia
# 1   259484657    1178180.0  2019-05-30 23:17:22               3  la famiglia
# 2  6364796956    1178180.0  2019-05-26 15:27:27               3  la famiglia
# 3   221389356  857670431.0  2019-05-30 21:41:15               2   green park
# 4   624306558  857670431.0   2019-05-30 7:56:50               3   green park
#
#                      city  cd         type_true
# 0  London, United Kingdom  GB            others
# 1  London, United Kingdom  GB            others
# 2  London, United Kingdom  GB            others
# 3  London, United Kingdom  GB  nature_and_parks
# 4  London, United Kingdom  GB  nature_and_parks

# %%
# Join both dataset
recsys_df_200 = recsys_df_200_true.join(zero_shot_df_200)
recsys_df_200.head()
# Out:
#    profile_id  location_id                  cts  sentiment_pred         name  \
# 0     4519805    1178180.0  2016-06-09 22:13:32               3  la famiglia
# 1   259484657    1178180.0  2019-05-30 23:17:22               3  la famiglia
# 2  6364796956    1178180.0  2019-05-26 15:27:27               3  la famiglia
# 3   221389356  857670431.0  2019-05-30 21:41:15               2   green park
# 4   624306558  857670431.0   2019-05-30 7:56:50               3   green park
#
#                      city  cd         type_true     sequence  \
# 0  London, United Kingdom  GB            others  la famiglia
# 1  London, United Kingdom  GB            others  la famiglia
# 2  London, United Kingdom  GB            others  la famiglia
# 3  London, United Kingdom  GB  nature_and_parks   green park
# 4  London, United Kingdom  GB  nature_and_parks   green park
#
#                                               labels  \
# 0  [others, sights_and_landmarks, fun_and_games, ...
# 1  [others, sights_and_landmarks, fun_and_games, ...
# 2  [others, sights_and_landmarks, fun_and_games, ...
# 3  [nature_and_parks, sights_and_landmarks, fun_a...
# 4  [nature_and_parks, sights_and_landmarks, fun_a...
#
#                                               scores  zero_shot_result
# 0  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 1  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 2  [0.22058841586112976, 0.16727125644683838, 0.0...            others
# 3  [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks
# 4  [0.506106436252594, 0.14772608876228333, 0.096...  nature_and_parks

# %%
# Save and export for zero shot comparison tuning
recsys_df_200.to_csv('./output/recsys_df_200_update.csv', index=False)

# %%
# Drop 'sequence','labels','scores' cols
recsys_df_200.drop(['sequence','labels','scores'], axis=1, inplace=True)
recsys_df_200.head()
# Out:
#    profile_id  location_id                  cts  sentiment_pred         name  \
# 0     4519805    1178180.0  2016-06-09 22:13:32               3  la famiglia
# 1   259484657    1178180.0  2019-05-30 23:17:22               3  la famiglia
# 2  6364796956    1178180.0  2019-05-26 15:27:27               3  la famiglia
# 3   221389356  857670431.0  2019-05-30 21:41:15               2   green park
# 4   624306558  857670431.0   2019-05-30 7:56:50               3   green park
#
#                      city  cd         type_true  zero_shot_result
# 0  London, United Kingdom  GB            others            others
# 1  London, United Kingdom  GB            others            others
# 2  London, United Kingdom  GB            others            others
# 3  London, United Kingdom  GB  nature_and_parks  nature_and_parks
# 4  London, United Kingdom  GB  nature_and_parks  nature_and_parks

# %%
# Check accuracy of pretrained model
accuracy_score(recsys_df_200['type_true'].values, recsys_df_200['zero_shot_result'].values)
# Out:
# 0.395

# %% [markdown]
# - The accuracy score of the pretrained model has improved when compared with more rows of data. We will attempt to compare with an additional 100 rows of hand-labelled location type to further gauge the performance of the pretrained model.

# %% [markdown]
# #### Using 300 rows for comparison

# %%
# Save and export next 100 rows for zero shot comparison
recsys_df_201to300 = recsys_df.iloc[201:301]
recsys_df_201to300.to_csv('./output/recsys_df_201to300.csv', index=False)

# %%
# %%time
zero_shot_df_201to300 = zero_shot_preds(recsys_df_201to300,classifier,['boat_tours_and_water_sports', 'pubs_and_nightlife', 'sights_and_landmarks', 'spas_and_wellness', 'fun_and_games', 'museums', 'classes_and_workshops', 'nature_and_parks', 'markets', 'neighbourhoods', 'others'])
# Out:
# 100%|█████████████████████████████████████████| 100/100 [09:41<00:00,  5.82s/it]
# CPU times: user 14min 6s, sys: 22.7 s, total: 14min 29s
# Wall time: 9min 41s
# /var/folders/w4/cdf3yttj10d7ynthq7lkp5fh0000gn/T/ipykernel_5135/2275498562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zero_shot_output"] = df["name"].progress_apply(

# %%
zero_shot_df_201to300.head()
# Out:
#                sequence                                             labels  \
# 0            souli food  [others, sights_and_landmarks, spas_and_wellne...
# 1            souli food  [others, sights_and_landmarks, spas_and_wellne...
# 2                 tesco  [spas_and_wellness, markets, sights_and_landma...
# 3  neal's yard remedies  [spas_and_wellness, nature_and_parks, sights_a...
# 4  neal's yard remedies  [spas_and_wellness, nature_and_parks, sights_a...
#
#                                               scores   zero_shot_result
# 0  [0.23861777782440186, 0.13402360677719116, 0.1...             others
# 1  [0.23861777782440186, 0.13402360677719116, 0.1...             others
# 2  [0.23894090950489044, 0.13002963364124298, 0.0...  spas_and_wellness
# 3  [0.2223985493183136, 0.1895524263381958, 0.178...  spas_and_wellness
# 4  [0.2223985493183136, 0.1895524263381958, 0.178...  spas_and_wellness

# %%
# Load true (hand labelled) location type
recsys_df_201to300_true = pd.read_csv('./output/recsys_df_201to300_true.csv')
print(recsys_df_201to300_true.shape)
recsys_df_201to300_true.head()
# Out:
# (100, 8)
#    profile_id   location_id                  cts  sentiment_pred  \
# 0  2240117505  2.314128e+08  2019-01-31 13:57:31               3
# 1   537500464  2.314128e+08   2018-10-30 7:49:01               3
# 2  8262374553  1.022884e+09  2018-07-30 15:39:19               3
# 3   400303321  1.019567e+09  2017-06-22 14:21:12               3
# 4   397556091  1.019567e+09  2018-01-07 21:55:06               2
#
#                    name                    city  cd type_true
# 0            souli food  London, United Kingdom  GB    others
# 1            souli food  London, United Kingdom  GB    others
# 2                 tesco  London, United Kingdom  GB    others
# 3  neal's yard remedies  London, United Kingdom  GB    others
# 4  neal's yard remedies  London, United Kingdom  GB    others

# %%
# Join both dataset
recsys_df_201to300 = recsys_df_201to300_true.join(zero_shot_df_201to300)
recsys_df_201to300.head()
# Out:
#    profile_id   location_id                  cts  sentiment_pred  \
# 0  2240117505  2.314128e+08  2019-01-31 13:57:31               3
# 1   537500464  2.314128e+08   2018-10-30 7:49:01               3
# 2  8262374553  1.022884e+09  2018-07-30 15:39:19               3
# 3   400303321  1.019567e+09  2017-06-22 14:21:12               3
# 4   397556091  1.019567e+09  2018-01-07 21:55:06               2
#
#                    name                    city  cd type_true  \
# 0            souli food  London, United Kingdom  GB    others
# 1            souli food  London, United Kingdom  GB    others
# 2                 tesco  London, United Kingdom  GB    others
# 3  neal's yard remedies  London, United Kingdom  GB    others
# 4  neal's yard remedies  London, United Kingdom  GB    others
#
#                sequence                                             labels  \
# 0            souli food  [others, sights_and_landmarks, spas_and_wellne...
# 1            souli food  [others, sights_and_landmarks, spas_and_wellne...
# 2                 tesco  [spas_and_wellness, markets, sights_and_landma...
# 3  neal's yard remedies  [spas_and_wellness, nature_and_parks, sights_a...
# 4  neal's yard remedies  [spas_and_wellness, nature_and_parks, sights_a...
#
#                                               scores   zero_shot_result
# 0  [0.23861777782440186, 0.13402360677719116, 0.1...             others
# 1  [0.23861777782440186, 0.13402360677719116, 0.1...             others
# 2  [0.23894090950489044, 0.13002963364124298, 0.0...  spas_and_wellness
# 3  [0.2223985493183136, 0.1895524263381958, 0.178...  spas_and_wellness
# 4  [0.2223985493183136, 0.1895524263381958, 0.178...  spas_and_wellness

# %%
# Drop 'sequence','labels','scores' cols
recsys_df_201to300.drop(['sequence','labels','scores'], axis=1, inplace=True)
recsys_df_201to300.head()
# Out:
#    profile_id   location_id                  cts  sentiment_pred  \
# 0  2240117505  2.314128e+08  2019-01-31 13:57:31               3
# 1   537500464  2.314128e+08   2018-10-30 7:49:01               3
# 2  8262374553  1.022884e+09  2018-07-30 15:39:19               3
# 3   400303321  1.019567e+09  2017-06-22 14:21:12               3
# 4   397556091  1.019567e+09  2018-01-07 21:55:06               2
#
#                    name                    city  cd type_true  \
# 0            souli food  London, United Kingdom  GB    others
# 1            souli food  London, United Kingdom  GB    others
# 2                 tesco  London, United Kingdom  GB    others
# 3  neal's yard remedies  London, United Kingdom  GB    others
# 4  neal's yard remedies  London, United Kingdom  GB    others
#
#     zero_shot_result
# 0             others
# 1             others
# 2  spas_and_wellness
# 3  spas_and_wellness
# 4  spas_and_wellness

# %%
# Concat the above 100 rows to first 200 rows
recsys_df_300 = pd.concat([recsys_df_200,recsys_df_201to300])

# %%
# Check accuracy of pretrained model
accuracy_score(recsys_df_300['type_true'].values, recsys_df_300['zero_shot_result'].values)
# Out:
# 0.2866666666666667

# %% [markdown]
# - The accuracy score of the pretrained model is worse.
# - The pretrained model is unable to categorise the locations based on the given categories.
# - As such, we will abort the use of this pretrained model.
# - We will proceed to building a collaborative-filtering recommender system without the location type feature.
